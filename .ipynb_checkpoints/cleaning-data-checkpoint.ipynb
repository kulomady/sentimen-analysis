# %%
import nltk
import re
from spacy.lang.id import Indonesian
import spacy
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd

# %%
stop_factory = StopWordRemoverFactory()
stopwords = stop_factory.get_stop_words()

# %%
df = pd.read_csv("jokowi.csv", encoding = "ISO-8859-1", names = ['tweet', 'sentiment'], na_values= ' ')
df.shape
# Out:
# (257, 2)

# %%
df[1:15]
# Out:
#                                                 tweet  sentiment
# 1   RT @KontraS: Hai! Berjumpa lagi dengan KontraS...        1.0
# 2   RT @fadlizon: Bohong lagi bohong lagi. Mikrofo...        0.0
# 3   RT @TheCebongers: Prawobo sentil Jokowi "Ugal2...        0.0
# 4   RT @bangzul_1988: @JajangRidwan19 @Hadisang70 ...        NaN
# 5   RT @narkosun: Jokowi dibilang ugal2an. jadi yg...        0.0
# 6   RT @IreneViena: Jika saya dapat membuktikan ke...        1.0
# 7   RT @fariji_lacak: Sdh Kubilang Dari "AWAL. Dem...        0.0
# 8   RT @mkhumaini: Hampir genap empat tahun pemeri...        0.0
# 9   jokowi Siapa pun Cawapres  intinya Jokowi haru...        1.0
# 10                                #2019jokowilanjut;1        1.0
# 11     #2019TetapJokowiâ¦" https://t.co/HrhQwh9Kth;1        1.0
# 12   @marierteman @fadlizon @Metro_TV @jokowi @kem...        0.0
# 13  RT @MbahUyok: Sejak "menjabat.. Anies:" satu p...        0.0
# 14  Jokowi dan Greenpeace: Bagaimana Industri Diha...        0.0

# %%
list(df)
df.set_index('tweet')
df = df.dropna()
df
# Out:
#                                                  tweet  sentiment
# 0          PARAHNYA DIKASI TEPUK TANGAN LAGI  BOS!!!;0        0.0
# 1    RT @KontraS: Hai! Berjumpa lagi dengan KontraS...        1.0
# 2    RT @fadlizon: Bohong lagi bohong lagi. Mikrofo...        0.0
# 3    RT @TheCebongers: Prawobo sentil Jokowi "Ugal2...        0.0
# 5    RT @narkosun: Jokowi dibilang ugal2an. jadi yg...        0.0
# 6    RT @IreneViena: Jika saya dapat membuktikan ke...        1.0
# 7    RT @fariji_lacak: Sdh Kubilang Dari "AWAL. Dem...        0.0
# 8    RT @mkhumaini: Hampir genap empat tahun pemeri...        0.0
# 9    jokowi Siapa pun Cawapres  intinya Jokowi haru...        1.0
# 10                                 #2019jokowilanjut;1        1.0
# 11      #2019TetapJokowiâ¦" https://t.co/HrhQwh9Kth;1        1.0
# 12    @marierteman @fadlizon @Metro_TV @jokowi @kem...        0.0
# 13   RT @MbahUyok: Sejak "menjabat.. Anies:" satu p...        0.0
# 14   Jokowi dan Greenpeace: Bagaimana Industri Diha...        0.0
# 15   RT @UtuhWibowo: Ssstt.. Ssstt.. HATTRICK! "ð
# ;0        0.0
# 16   RS" dipecat dari Timses Prabowo Sandi negara t...        0.0
# 17   RT @yudimeno: @asrarkrm @jokowi Pidato diketik...        0.0
# 18   RT @cahkelendi: Kami &gt;1100 #Ex_VIJ siap men...        1.0
# 19   RT @SpionaseNKRI: Jujur, gw bingung!! " Gereja...        0.0
# 20   Mang haus pujian giliran dikritik ga mau kerja...        0.0
# 21   RT @marierteman: tergerus itu = TEKOR kan "? @...        0.0
# 22   RT @erwinsudarman: Kala BPJS defisit menteri a...        0.0
# 23   RT @AkunTofa: Jokowi KEOK. Percayalah. https:/...        0.0
# 24   Emang yakin kalau @prabowo menang akan lebih b...        1.0
# 25   "@humeruscattery1 @GunRomli @jokowi Blunder se...        1.0
# 26   RT @CNNIndonesia: Bawaslu Duga Jokowi-Maruf Cu...        0.0
# 27   RT @RizmaWidiono: Jokowi Tinjau Pembangunan Ru...        1.0
# 28                               #2019TetapJokowi" ";1        1.0
# 29   RT @dr_gundi: Ya Allah pak @jokowi 4 9 T itu b...        0.0
# 30   RT @jokowi: Di Sumbawa saya saksikan bantuan p...        0.0
# ..                                                 ...        ...
# 223  #JokowiLagi #bersihmerakyatkerjanyata #Jokowi2...        1.0
# 224  RT @MbahUyok: Sejak "menjabat.. Anies:" satu p...        0.0
# 226  #JokowiLagi #bersihmerakyatkerjanyata #Jokowi2...        1.0
# 227  RT @RadPlague: Kalau pendukung Jokowi kritis k...        0.0
# 228  RT @JayaSatrianie: Natalius Pigai " " Tidak ad...        0.0
# 231  RT @RachlanNashidik: Yakin Jokowi kalah. https...        0.0
# 232  @AksiKamisan @elisa_jkt @jokowi Tau ah geyyyya...        0.0
# 233  RT @RizmaWidiono: Luhut Minta Pengkritik Jokow...        1.0
# 234                              #2019TetapJokowi" ";1        1.0
# 235  #2019JokowiMarufAmin" âï¸ https://t.co/1msz...        1.0
# 236  RT @IreneViena: Jika saya dapat membuktikan ke...        1.0
# 237  RT @Dennysiregar7: Pagi pakde @jokowi. Pasti e...        1.0
# 238  RT @RestyCayah: Nah loh . @jokowi dan antek2ny...        0.0
# 239  RT @ronavioleta: soalnya prabowo tahu diri kal...        1.0
# 240  RT @marierteman: waktu RS ngaku "bohong..... p...        0.0
# 241  RT @putrabanten80: Untuk kesekian kali nya jub...        0.0
# 242  RT @Dahnilanzar: Pak @jokowi BPJS itu langsung...        0.0
# 243  Legislator: Komitmen Jokowi Soal Bantuan Gempa...        1.0
# 244  Lewat Dana Desa  Jokowi Dinilai Sukses Bangun ...        1.0
# 245                                      #JokowiLagi;1        1.0
# 246                              #2019TetapJokowi" ";1        1.0
# 247                                  #2019JokowiAmin;1        1.0
# 249  RT @dr_gundi: Ya Allah pak @jokowi 4 9 T itu b...        0.0
# 250  RT @ASapardan: "Twips Hanya" dijaman presiden ...        1.0
# 251  RT @SarishaBening: Penyerahan Sertifikat Hak a...        1.0
# 252   @TirtoID Saya Jokower tapi mengkritik keras s...        0.0
# 253  Siapa jokowi pun Cawapres intinya Jokowi harus...        1.0
# 254                                #2019jokowilanjut;1        1.0
# 255  #2019TetapJokowi" @jokowiâ¦ https://t.co/IVxi...        1.0
# 256  4 Tahun Kepemimpinan Jokowi Sejumlah Masalah I...        0.0
#
# [214 rows x 2 columns]

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
def cleanningTweet(text):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|(RT)|([:1])|([:0])"," ",text).split())

# %%
def stopwordRemove(text):
    filtered_sentence = [w for w in text if not w in stopwords]
    resultStringTokenize = ''.join(filtered_sentence)
    return resultStringTokenize

# %%
def prepocessingText(text):
    return stemmingWord(stopwordRemove(cleanningTweet(text)))

# %%
new_df = df.fillna(method="ffill")

# %%
def stemmingWord(sentence):
    nlp = Indonesian()  # use directly
    nlp = spacy.blank('id')  # blank instance'
    text = nlp(sentence)
    token_kata = [token.lemma_ for token in text]
    resultWithSpacy = ' '.join(token_kata)
    return resultWithSpacy.lower()

# %%
inp = [{'c1':10, 'c2':100}, {'c1':11,'c2':110}, {'c1':12,'c2':120}]

all_data = []
for index, row in new_df.iterrows():
    all_data.append(tuple((cleanningTweet(row['tweet']), row['sentiment'])))

# %%
clean_data = pd.DataFrame(all_data,  columns = ["sentiment", "label"])
clean_data.sav("clean_jokowi.csv")

# %% [markdown]
# ##### Stemming words

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
stemmerFactory = StemmerFactory()
stemmer = stemmerFactory.create_stemmer()
hasilStemmer = stemmer.stem(stopwordResult)
print(hasilStemmer)

# %%
a = clean_data.sentiment.str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_dist = nltk.FreqDist(words)
# word_dist.most_common()

# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer

# df = pd.read_table("/tmp/test.csv", sep="\s+")
# v = TfidfVectorizer()
# x = v.fit_transform(df['text'])

# df1 = pd.DataFrame(x.toarray(), columns=v.get_feature_names())
# df.drop('text', axis=1, inplace=True)
# res = pd.concat([df, df1], axis=1)
# Out:
# [('0', 5),
#  ('lagi', 4),
#  ('jokowi', 4),
#  ('4', 3),
#  ('yg', 3),
#  ('tahun', 2),
#  ('pemerintahan', 2),
#  ('bohong', 2),
#  ('sentil', 2),
#  ('ugal2an', 2),
#  ('perintah', 2),
#  ('dari', 2),
#  ('rp', 2),
#  ('triliun', 2),
#  ('parahnya', 1),
#  ('dikasi', 1),
#  ('tepuk', 1),
#  ('tangan', 1),
#  ('bos', 1),
#  ('hai', 1),
#  ('berjumpa', 1),
#  ('dengan', 1),
#  ('kontras', 1),
#  ('yang', 1),
#  ('akan', 1),
#  ('kembali', 1),
#  ('nyicil', 1),
#  ('bahas', 1),
#  ('laporan', 1),
#  ('evaluasi', 1),
#  ('kinerja', 1),
#  ('mikrofon', 1),
#  ('dimatikan', 1),
#  ('dulu', 1),
#  ('dong', 1),
#  ('p', 1),
#  ('lbp', 1),
#  ('prawobo', 1),
#  ('lalu', 1),
#  ('bung', 1),
#  ('adian', 1),
#  ('balas', 1),
#  ('bukan', 1),
#  ('tapi', 1),
#  ('pukul', 1),
#  ('telak', 1),
#  ('ke', 1),
#  ('prabowo', 1),
#  ('ug', 1),
#  ('dibilang', 1),
#  ('jadi', 1),
#  ('bangun', 1),
#  ('infrastruktur', 1),
#  ('bagi2', 1),
#  ('sertifikat', 1),
#  ('lapang', 1),
#  ('kerja', 1),
#  ('bangkit', 1),
#  ('listrik', 1),
#  ('jalan', 1),
#  ('tol', 1),
#  ('be', 1),
#  ('jika', 1),
#  ('saya', 1),
#  ('dapat', 1),
#  ('bukti', 1),
#  ('putus', 1),
#  ('kait', 1),
#  ('takeover', 1),
#  ('saham', 1),
#  ('mayority', 1),
#  ('freeport', 1),
#  ('dilakukan', 1),
#  ('sekarang', 1),
#  ('adalah', 1),
#  ('tind', 1),
#  ('lacak', 1),
#  ('sdh', 1),
#  ('kubilang', 1),
#  ('awal', 1),
#  ('demokrat', 1),
#  ('pks', 1),
#  ('amp', 1),
#  ('pan', 1),
#  ('fokus', 1),
#  ('pd', 1),
#  ('pilleg', 1),
#  ('timbang', 1),
#  ('pilpres', 1),
#  ('mereka', 1),
#  ('tdk', 1),
#  ('ingin', 1),
#  ('hilang', 1),
#  ('wakilnya', 1),
#  ('di', 1),
#  ('hampir', 1),
#  ('genap', 1),
#  ('empat', 1),
#  ('catat', 1),
#  ('total', 1),
#  ('utang', 1),
#  ('capai', 1),
#  ('6', 1),
#  ('naik', 1),
#  ('kitar', 1),
#  ('8', 1),
#  ('5', 1),
#  ('pos', 1),
#  ('siapa', 1),
#  ('pun', 1),
#  ('cawapres', 1),
#  ('intinya', 1),
#  ('harus', 1),
#  ('2', 1),
#  ('periode', 1)]
